# %%
import tensorflow as tf
import numpy as np
import gym
import random
from collections import deque
# Out:
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.summary API due to missing TensorBoard installation.

# %%
num_episodes = 500
num_exploration_episodes = 100  
max_len_episode = 10000 
batch_size = 32           
gamma = 1.  
final_epsilon = 0.01
initial_epsilon = 1.         # epsilon for epsilon-greedy: epsilon probability to explore

# %%
# class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
#     def __init__(self):
#         super(CustomSchedule, self).__init__()
    
#     def __call__(self, step):

#         return 1.0e-3*(0.99**step)

# %%
learning_rate = 0.001

# %%
class QNetwork(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.dense1 = tf.keras.layers.Dense(units=24, activation=tf.nn.relu)
        self.dense2 = tf.keras.layers.Dense(units=24, activation=tf.nn.relu)
        self.dense3 = tf.keras.layers.Dense(units=2)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        return x

    def predict(self, inputs):
        q_values = self(inputs)
        return tf.argmax(q_values, axis=-1)

# %%
env = gym.make('CartPole-v1') 
model = QNetwork()
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
replay_buffer = deque(maxlen=10000)
for episode_id in range(num_episodes):
    state = env.reset()             # init state
    epsilon = max(                  # dynamic changing epsilon (explore rate for epsilon greedy)
        initial_epsilon * (num_exploration_episodes - episode_id) / num_exploration_episodes,
        final_epsilon)
    for t in range(max_len_episode):
        env.render()                                # draw
        if random.random() < epsilon:               # by random choose explore
            action = env.action_space.sample()      # random pick one action
        else: # exploit 
            action = model.predict(np.expand_dims(state, axis=0)).numpy() 
            action = action[0]

        # excute action: return next_state, reward, if game is over, and extra info
        next_state, reward, done, info = env.step(action)
        if done:
            reward = -10.  # game over => negative reward
        # append (state, action, reward, next_state, done) to replay_buffer
        replay_buffer.append((state, action, reward, next_state, 1 if done else 0))
        # update state
        state = next_state

        if done:
#             print("episode %d, epsilon %f, score %d" % (episode_id, epsilon, t))
            print("episode %d, score %d" % (episode_id, t))
            break

        if len(replay_buffer) >= batch_size:
            # get a batch of state, action, reward, ext_state, done
            batch_state, batch_action, batch_reward, batch_next_state, batch_done = zip(
                *random.sample(replay_buffer, batch_size))
            batch_state, batch_reward, batch_next_state, batch_done = \
                [np.array(a, dtype=np.float32) for a in [batch_state, batch_reward, batch_next_state, batch_done]]
            batch_action = np.array(batch_action, dtype=np.int32)

            q_value = model(batch_next_state)
            # Bellman Equation
            y = batch_reward + (gamma * tf.reduce_max(q_value, axis=1)) * (1 - batch_done)
            with tf.GradientTape() as tape:
                loss = tf.keras.losses.mean_squared_error(  # Square
                    y_true=y,
                    y_pred=tf.reduce_sum(model(batch_state) * tf.one_hot(batch_action, depth=2), axis=1)
                )
            grads = tape.gradient(loss, model.variables)
            optimizer.apply_gradients(grads_and_vars=zip(grads, model.variables))
# Out:
# episode 0, score 19
# episode 1, score 32
# episode 2, score 62
# episode 3, score 14
# WARNING:tensorflow:Layer q_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# WARNING:tensorflow:Layer q_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# episode 4, score 13
# episode 5, score 44
# episode 6, score 10
# episode 7, score 30
# episode 8, score 12
# episode 9, score 19
# episode 10, score 25
# episode 11, score 13
# episode 12, score 10
# episode 13, score 10
# episode 14, score 15
# episode 15, score 14
# episode 16, score 15
# episode 17, score 21
# episode 18, score 18
# episode 19, score 19
# episode 20, score 23
# episode 21, score 35
# episode 22, score 10
# episode 23, score 18
# episode 24, score 18
# episode 25, score 12
# episode 26, score 15
# episode 27, score 17
# episode 28, score 17
# episode 29, score 18
# episode 30, score 14
# episode 31, score 20
# episode 32, score 8
# episode 33, score 17
# episode 34, score 18
# episode 35, score 14
# episode 36, score 15
# episode 37, score 7
# episode 38, score 12
# episode 39, score 17
# episode 40, score 9
# episode 41, score 14
# episode 42, score 11
# episode 43, score 12
# episode 44, score 19
# episode 45, score 13
# episode 46, score 17
# episode 47, score 17
# episode 48, score 76
# episode 49, score 29
# episode 50, score 16
# episode 51, score 31
# episode 52, score 39
# episode 53, score 81
# episode 54, score 41
# episode 55, score 23
# episode 56, score 77
# episode 57, score 70
# episode 58, score 153
# episode 59, score 38
# episode 60, score 39
# episode 61, score 104
# episode 62, score 52
# episode 63, score 58
# episode 64, score 50
# episode 65, score 77
# episode 66, score 95
# episode 67, score 115
# episode 68, score 105
# episode 69, score 143
# episode 70, score 120
# episode 71, score 126
# episode 72, score 165
# episode 73, score 157
# episode 74, score 181
# episode 75, score 119
# episode 76, score 89
# episode 77, score 64
# episode 78, score 153
# episode 79, score 240
# episode 80, score 166
# episode 81, score 135
# episode 82, score 194
# episode 83, score 129
# episode 84, score 155
# episode 85, score 143
# episode 86, score 164
# episode 87, score 199
# episode 88, score 176
# episode 89, score 151
# episode 90, score 148
# episode 91, score 137
# episode 92, score 149
# episode 93, score 164
# episode 94, score 170
# episode 95, score 186
# episode 96, score 185
# episode 97, score 156
# episode 98, score 207
# episode 99, score 208
# episode 100, score 217
# episode 101, score 331
# episode 102, score 224
# episode 103, score 176
# episode 104, score 191
# episode 105, score 191
# episode 106, score 153
# episode 107, score 252
# episode 108, score 296
# episode 109, score 179
# episode 110, score 167
# episode 111, score 476
# episode 112, score 499
# episode 113, score 205
# episode 114, score 166
# episode 115, score 160
# episode 116, score 224
# episode 117, score 152
# episode 118, score 165
# episode 119, score 196
# episode 120, score 193
# episode 121, score 252
# episode 122, score 198
# episode 123, score 168
# episode 124, score 161
# episode 125, score 174
# episode 126, score 327
# episode 127, score 432
# episode 128, score 203
# episode 129, score 279
# episode 130, score 265
# episode 131, score 324
# episode 132, score 417
# episode 133, score 326
# episode 134, score 307
# episode 135, score 446
# episode 136, score 499
# episode 137, score 301
# episode 138, score 499
# episode 139, score 368
# episode 140, score 499
# episode 141, score 499
# episode 142, score 499
# episode 143, score 499
# episode 144, score 252
# episode 145, score 499
# episode 146, score 499
# episode 147, score 499
# episode 148, score 303
# episode 149, score 499
# episode 150, score 499
# episode 151, score 499
# episode 152, score 382
# episode 153, score 281
# episode 154, score 142
# episode 155, score 13
# episode 156, score 10
# episode 157, score 11
# episode 158, score 10
# episode 159, score 13
# episode 160, score 9
# episode 161, score 9
# episode 162, score 8
# episode 163, score 9
# episode 164, score 27
# episode 165, score 10
# episode 166, score 14
# episode 167, score 10
# episode 168, score 9
# episode 169, score 9
# episode 170, score 8
# episode 171, score 126
# episode 172, score 10
# episode 173, score 8
# episode 174, score 9
# episode 175, score 8
# episode 176, score 8
# episode 177, score 8
# episode 178, score 8
# episode 179, score 9
# episode 180, score 9
# episode 181, score 8
# episode 182, score 7
# episode 183, score 9
# episode 184, score 9
# episode 185, score 9
# episode 186, score 8
# episode 187, score 9
# episode 188, score 10
# episode 189, score 9
# episode 190, score 8
# episode 191, score 9
# episode 192, score 7
# episode 193, score 9
# episode 194, score 10
# episode 195, score 9
# episode 196, score 178
# episode 197, score 10
# episode 198, score 8
# episode 199, score 10
# episode 200, score 10
# episode 201, score 11
# episode 202, score 9
# episode 203, score 9
# episode 204, score 9
# episode 205, score 8
# episode 206, score 9
# episode 207, score 8
# episode 208, score 9
# episode 209, score 9
# episode 210, score 8
# episode 211, score 10
# episode 212, score 8
# episode 213, score 7
# episode 214, score 8
# episode 215, score 9
# episode 216, score 8
# episode 217, score 11
# episode 218, score 10
# episode 219, score 11
# episode 220, score 12
# episode 221, score 9
# episode 222, score 11
# episode 223, score 12
# episode 224, score 13
# episode 225, score 14
# episode 226, score 16
# episode 227, score 12
# episode 228, score 13
# episode 229, score 14
# episode 230, score 18
# episode 231, score 37
# episode 232, score 96
# episode 233, score 207
# episode 234, score 48
# episode 235, score 18
# episode 236, score 31
# episode 237, score 34
# episode 238, score 42
# episode 239, score 19
# episode 240, score 13
# episode 241, score 14
# episode 242, score 16
# episode 243, score 12
# episode 244, score 10
# episode 245, score 14
# episode 246, score 11
# episode 247, score 9
# episode 248, score 12
# episode 249, score 10
# episode 250, score 8
# episode 251, score 10
# episode 252, score 11
# episode 253, score 10
# episode 254, score 11
# episode 255, score 10
# episode 256, score 10
# episode 257, score 9
# episode 258, score 8
# episode 259, score 10
# episode 260, score 12
# episode 261, score 13
# episode 262, score 14
# episode 263, score 13
# episode 264, score 14
# episode 265, score 12
# episode 266, score 37
# episode 267, score 44
# episode 268, score 21
# episode 269, score 36
# episode 270, score 39
# episode 271, score 35
# episode 272, score 29
# episode 273, score 30
# episode 274, score 30
# episode 275, score 33
# episode 276, score 37
# episode 277, score 42
# episode 278, score 50
# episode 279, score 48
# episode 280, score 45
# episode 281, score 41
# episode 282, score 48
# episode 283, score 84
# episode 284, score 70
# episode 285, score 52
# episode 286, score 70
# episode 287, score 52
# episode 288, score 77
# episode 289, score 52
# episode 290, score 62
# episode 291, score 53
# episode 292, score 49
# episode 293, score 49
# episode 294, score 58
# episode 295, score 56
# episode 296, score 64
# episode 297, score 39
# episode 298, score 47
# episode 299, score 77
# episode 300, score 68
# episode 301, score 54
# episode 302, score 50
# episode 303, score 51
# episode 304, score 50
# episode 305, score 46
# episode 306, score 54
# episode 307, score 64
# episode 308, score 60
# episode 309, score 89
# episode 310, score 59
# episode 311, score 80
# episode 312, score 79
# episode 313, score 85
# episode 314, score 74
# episode 315, score 150
# episode 316, score 81
# episode 317, score 93
# episode 318, score 226
# episode 319, score 104
# episode 320, score 81
# episode 321, score 138
# episode 322, score 105
# episode 323, score 135
# episode 324, score 116
# episode 325, score 198
# episode 326, score 150
# episode 327, score 230
# episode 328, score 149
# episode 329, score 146
# episode 330, score 116
# episode 331, score 104
# episode 332, score 175
# episode 333, score 117
# episode 334, score 90
# episode 335, score 80
# episode 336, score 113
# episode 337, score 136
# episode 338, score 409
# episode 339, score 110
# episode 340, score 101
# episode 341, score 155
# episode 342, score 87
# episode 343, score 160
# episode 344, score 110
# episode 345, score 135
# episode 346, score 127
# episode 347, score 123
# episode 348, score 114
# episode 349, score 163
# episode 350, score 162
# episode 351, score 313
# episode 352, score 499
# episode 353, score 215
# episode 354, score 148
# episode 355, score 218
# episode 356, score 207
# episode 357, score 131
# episode 358, score 105
# episode 359, score 91
# episode 360, score 62
# episode 361, score 48
# episode 362, score 38
# episode 363, score 33
# episode 364, score 29
# episode 365, score 32
# episode 366, score 35
# episode 367, score 30
# episode 368, score 33
# episode 369, score 58
# episode 370, score 499
# episode 371, score 404
# episode 372, score 499
# episode 373, score 499
# episode 374, score 466
# episode 375, score 285
# episode 376, score 122
# episode 377, score 9
# episode 378, score 9
# episode 379, score 10
# episode 380, score 10
# episode 381, score 11
# episode 382, score 11
# episode 383, score 8
# episode 384, score 9
# episode 385, score 9
# episode 386, score 8
# episode 387, score 9
# episode 388, score 8
# episode 389, score 9
# episode 390, score 10
# episode 391, score 8
# episode 392, score 9
# episode 393, score 9
# episode 394, score 9
# episode 395, score 8
# episode 396, score 11
# episode 397, score 11
# episode 398, score 12
# episode 399, score 16
# episode 400, score 200
# episode 401, score 9
# episode 402, score 9
# episode 403, score 8
# episode 404, score 9
# episode 405, score 9
# episode 406, score 7
# episode 407, score 7
# episode 408, score 7
# episode 409, score 9
# episode 410, score 7
# episode 411, score 9
# episode 412, score 8
# episode 413, score 9
# episode 414, score 9
# episode 415, score 11
# episode 416, score 9
# episode 417, score 10
# episode 418, score 10
# episode 419, score 7
# episode 420, score 8
# episode 421, score 9
# episode 422, score 8
# episode 423, score 8
# episode 424, score 7
# episode 425, score 7
# episode 426, score 8
# episode 427, score 10
# episode 428, score 10
# episode 429, score 13
# episode 430, score 22
# episode 431, score 10
# episode 432, score 10
# episode 433, score 31
# episode 434, score 26
# episode 435, score 30
# episode 436, score 99
# episode 437, score 176
# episode 438, score 165
# episode 439, score 172
# episode 440, score 171
# episode 441, score 499
# episode 442, score 214
# episode 443, score 314
# episode 444, score 282
# episode 445, score 274
# episode 446, score 260
# episode 447, score 172
# episode 448, score 229
# episode 449, score 379
# episode 450, score 499
# episode 451, score 460
# episode 452, score 499
# episode 453, score 499
# episode 454, score 370
# episode 455, score 286
# episode 456, score 499
# episode 457, score 499
# episode 458, score 298
# episode 459, score 233
# episode 460, score 271
# episode 461, score 292
# episode 462, score 252
# episode 463, score 252
# episode 464, score 221
# episode 465, score 242
# episode 466, score 221
# episode 467, score 265
# episode 468, score 255
# episode 469, score 259
# episode 470, score 301
# episode 471, score 329
# episode 472, score 344
# episode 473, score 319
# episode 474, score 499
# episode 475, score 499
# episode 476, score 499
